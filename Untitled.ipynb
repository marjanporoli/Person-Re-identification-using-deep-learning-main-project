# %%
# # Import the zipfile module
# import zipfile

# # Specify the path to the zip file
# zip_ref = zipfile.ZipFile(r"C:\Users\shifz\OneDrive\Desktop\reid_frontend\archive (9).zip", 'r')

# # Extract all the contents of the zip file
# zip_ref.extractall(r"C:\Users\shifz\OneDrive\Desktop\reid_frontend")

# # Close the zip file
# zip_ref.close()

# %%
# !pip install -q git+https://github.com/albumentations-team/albumentations -q

# !pip install -q segmentation-models-pytorch
# !pip install -q opencv-contrib-python

# !git clone https://github.com/parth1620/Person-Re-Id-Dataset


import sys
sys.path.append("/kaggle/working/Person-Re-Id-Dataset")

# %%
pip install numpy==1.24
# Out:
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# albumentations 1.4.2 requires numpy>=1.24.4, but you have numpy 1.24.0 which is incompatible.
# seaborn 0.12.2 requires numpy!=1.24.0,>=1.17, but you have numpy 1.24.0 which is incompatible.
# ...
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/14.8 MB 825.8 kB/s eta 0:00:18
#     --------------------------------------- 0.2/14.8 MB 2.3 MB/s eta 0:00:07
#    - -------------------------------------- 0.4/14.8 MB 2.7 MB/s eta 0:00:06
#    - -------------------------------------- 0.6/14.8 MB 3.2 MB/s eta 0:00:05
# ...

# %%
# !git clone https://github.com/parth1620/Person-Re-Id-Dataset
# Out:
# Cloning into 'Person-Re-Id-Dataset'...
# Updating files:  10% (1383/12939)
# Updating files:  11% (1424/12939)
# Updating files:  12% (1553/12939)
# Updating files:  13% (1683/12939)
# Updating files:  14% (1812/12939)
# Updating files:  15% (1941/12939)
# Updating files:  16% (2071/12939)
# Updating files:  17% (2200/12939)
# Updating files:  18% (2330/12939)
# Updating files:  19% (2459/12939)
# Updating files:  20% (2588/12939)
# Updating files:  21% (2718/12939)
# Updating files:  21% (2741/12939)
# Updating files:  22% (2847/12939)
# Updating files:  23% (2976/12939)
# Updating files:  24% (3106/12939)
# Updating files:  25% (3235/12939)
# Updating files:  26% (3365/12939)
# Updating files:  27% (3494/12939)
# Updating files:  28% (3623/12939)
# Updating files:  29% (3753/12939)
# Updating files:  30% (3882/12939)
# Updating files:  31% (4012/12939)
# Updating files:  32% (4141/12939)
# Updating files:  32% (4154/12939)
# Updating files:  33% (4270/12939)
# ...

# %%
import sys
sys.path.append("/kaggle/working/Person-Re-Id-Dataset")
